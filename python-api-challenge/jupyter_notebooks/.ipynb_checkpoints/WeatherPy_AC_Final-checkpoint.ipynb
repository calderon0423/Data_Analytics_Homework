# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from scipy.stats import linregress
from datetime import datetime
import time

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name


#If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
#cities = [citipy.nearest_city(lat_lng[0],lat_lng[1]).city_name for lat_lng in lat_lngs if citipy.nearest_city(lat_lng[0],lat_lng[1]).city_name not in cities]

# Print the city count to confirm sufficient count
print(f"There are {len(cities)} unique cities.")
# Out:
# There are 634 unique cities.

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#api.openweathermap.org/data/2.5/weather?q={city name}&appid={your api key}
url = 'https://api.openweathermap.org/data/2.5/weather'
units = "metric"
temp = []
lat = []
lon = []
humidity_percent = []
cloudiness_percent = []
wind_speed = []
city_list = []
request_num = [x+1 for x in range(len(cities))]


for city in cities: 
    record = cities.index(city) + 1
    #set_num = 
    if record % 20 == 0: 
        #add a one second interval between queries to stay within API query limits 
        time.sleep(1)
        
        weather_response = requests.get(url, params={'appid': weather_api_key,'q': city,'units': units})
        response_json = weather_response.json()
        record = cities.index(city) + 1

        try: 
            city_list.append(response_json['name'])
            temp.append(response_json['main']['temp_max'])
            lat.append(response_json['coord']['lat'])
            lon.append(response_json['coord']['lon'])
            humidity_percent.append(response_json['main']['humidity'])
            cloudiness_percent.append(response_json['clouds']['all'])
            wind_speed.append(response_json['wind']['speed'])
            print(f"Processing Record {record} of Set 1 | {city}")

        except: 
            print(f"City not found. Skipping...")
            
        
    else:
        weather_response = requests.get(url, params={'appid': weather_api_key,'q': city, 'units': units})
        response_json = weather_response.json()
        record = cities.index(city) + 1

        try: 
            city_list.append(response_json['name'])
            temp.append(response_json['main']['temp_max'])
            lat.append(response_json['coord']['lat'])
            lon.append(response_json['coord']['lon'])
            humidity_percent.append(response_json['main']['humidity'])
            cloudiness_percent.append(response_json['clouds']['all'])
            wind_speed.append(response_json['wind']['speed'])
            print(f"Processing Record {record} of Set 1 | {city}")

        except: 
            print(f"City not found. Skipping...")
# Out:
# Processing Record 1 of Set 1 | pakxe
# Processing Record 2 of Set 1 | taltal
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | kodiak
# Processing Record 6 of Set 1 | esperance
# Processing Record 7 of Set 1 | ayan
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | todos santos
# Processing Record 11 of Set 1 | ternate
# Processing Record 12 of Set 1 | saskylakh
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | oeiras
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | qui nhon
# Processing Record 20 of Set 1 | grand gaube
# Processing Record 21 of Set 1 | ponta do sol
# Processing Record 22 of Set 1 | eyl
# City not found. Skipping...
# Processing Record 24 of Set 1 | rio gallegos
# Processing Record 25 of Set 1 | svetlogorsk
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | morant bay
# Processing Record 28 of Set 1 | coihueco
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | stornoway
# Processing Record 31 of Set 1 | narsaq
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | arlit
# Processing Record 34 of Set 1 | faanui
# Processing Record 35 of Set 1 | ostrovnoy
# Processing Record 36 of Set 1 | kariba
# Processing Record 37 of Set 1 | haines junction
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | praia
# Processing Record 40 of Set 1 | saint-philippe
# Processing Record 41 of Set 1 | yarega
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | cherskiy
# Processing Record 46 of Set 1 | flinders
# Processing Record 47 of Set 1 | fare
# Processing Record 48 of Set 1 | leningradskiy
# Processing Record 49 of Set 1 | grindavik
# Processing Record 50 of Set 1 | new norfolk
# City not found. Skipping...
# Processing Record 52 of Set 1 | butaritari
# Processing Record 53 of Set 1 | vestmannaeyjar
# Processing Record 54 of Set 1 | mackay
# Processing Record 55 of Set 1 | east london
# Processing Record 56 of Set 1 | benghazi
# Processing Record 57 of Set 1 | latung
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 60 of Set 1 | amga
# Processing Record 61 of Set 1 | calamar
# Processing Record 62 of Set 1 | gamba
# Processing Record 63 of Set 1 | georgetown
# Processing Record 64 of Set 1 | wajir
# Processing Record 65 of Set 1 | ures
# Processing Record 66 of Set 1 | san policarpo
# Processing Record 67 of Set 1 | chapada dos guimaraes
# Processing Record 68 of Set 1 | busselton
# Processing Record 69 of Set 1 | sibolga
# Processing Record 70 of Set 1 | zhigansk
# Processing Record 71 of Set 1 | polovinnoye
# Processing Record 72 of Set 1 | hithadhoo
# Processing Record 73 of Set 1 | matagami
# Processing Record 74 of Set 1 | guantanamo
# Processing Record 75 of Set 1 | bay city
# Processing Record 76 of Set 1 | sao joao da barra
# Processing Record 77 of Set 1 | vaini
# City not found. Skipping...
# Processing Record 79 of Set 1 | mandalgovi
# Processing Record 80 of Set 1 | port elizabeth
# Processing Record 81 of Set 1 | mahebourg
# City not found. Skipping...
# Processing Record 83 of Set 1 | jamestown
# Processing Record 84 of Set 1 | yulara
# Processing Record 85 of Set 1 | luderitz
# Processing Record 86 of Set 1 | waipawa
# Processing Record 87 of Set 1 | victoria
# City not found. Skipping...
# Processing Record 89 of Set 1 | huangpi
# Processing Record 90 of Set 1 | viedma
# Processing Record 91 of Set 1 | rantepao
# Processing Record 92 of Set 1 | tuktoyaktuk
# Processing Record 93 of Set 1 | lorengau
# Processing Record 94 of Set 1 | koson
# Processing Record 95 of Set 1 | mizan teferi
# City not found. Skipping...
# Processing Record 97 of Set 1 | torbay
# Processing Record 98 of Set 1 | yar-sale
# Processing Record 99 of Set 1 | mar del plata
# Processing Record 100 of Set 1 | lavrentiya
# Processing Record 101 of Set 1 | dunedin
# Processing Record 102 of Set 1 | castro
# Processing Record 103 of Set 1 | vanimo
# Processing Record 104 of Set 1 | avarua
# Processing Record 105 of Set 1 | brooks
# Processing Record 106 of Set 1 | ancud
# Processing Record 107 of Set 1 | ixtapa
# Processing Record 108 of Set 1 | kropotkin
# Processing Record 109 of Set 1 | mananjary
# Processing Record 110 of Set 1 | muroto
# Processing Record 111 of Set 1 | penzance
# Processing Record 112 of Set 1 | puerto gaitan
# City not found. Skipping...
# Processing Record 114 of Set 1 | hasaki
# Processing Record 115 of Set 1 | vincennes
# Processing Record 116 of Set 1 | faya
# Processing Record 117 of Set 1 | douglas
# Processing Record 118 of Set 1 | ballina
# Processing Record 119 of Set 1 | saryg-sep
# Processing Record 120 of Set 1 | biak
# Processing Record 121 of Set 1 | nhulunbuy
# Processing Record 122 of Set 1 | pangnirtung
# Processing Record 123 of Set 1 | ojinaga
# Processing Record 124 of Set 1 | dikson
# Processing Record 125 of Set 1 | ilulissat
# Processing Record 126 of Set 1 | yellowknife
# Processing Record 127 of Set 1 | lebu
# Processing Record 128 of Set 1 | boralday
# Processing Record 129 of Set 1 | kaitangata
# Processing Record 130 of Set 1 | khatanga
# Processing Record 131 of Set 1 | college
# Processing Record 132 of Set 1 | zhicheng
# Processing Record 133 of Set 1 | santa maria
# City not found. Skipping...
# Processing Record 135 of Set 1 | sola
# Processing Record 136 of Set 1 | graaff-reinet
# Processing Record 137 of Set 1 | radeberg
# Processing Record 138 of Set 1 | qaqortoq
# Processing Record 139 of Set 1 | kirkwall
# Processing Record 140 of Set 1 | vila velha
# Processing Record 141 of Set 1 | mardin
# Processing Record 142 of Set 1 | palmer
# City not found. Skipping...
# Processing Record 144 of Set 1 | shache
# Processing Record 145 of Set 1 | hermanus
# Processing Record 146 of Set 1 | nouadhibou
# Processing Record 147 of Set 1 | tytuvenai
# Processing Record 148 of Set 1 | bethel
# Processing Record 149 of Set 1 | longyearbyen
# Processing Record 150 of Set 1 | husavik
# Processing Record 151 of Set 1 | den helder
# Processing Record 152 of Set 1 | chalan
# Processing Record 153 of Set 1 | iqaluit
# Processing Record 154 of Set 1 | kruisfontein
# Processing Record 155 of Set 1 | bambous virieux
# Processing Record 156 of Set 1 | urucara
# Processing Record 157 of Set 1 | nosy varika
# Processing Record 158 of Set 1 | templemore
# Processing Record 159 of Set 1 | sandwick
# Processing Record 160 of Set 1 | kokuy
# Processing Record 161 of Set 1 | hobart
# Processing Record 162 of Set 1 | ruthin
# Processing Record 163 of Set 1 | airai
# Processing Record 164 of Set 1 | karratha
# Processing Record 165 of Set 1 | sterling
# Processing Record 166 of Set 1 | maryville
# Processing Record 167 of Set 1 | monrovia
# Processing Record 168 of Set 1 | qaanaaq
# Processing Record 169 of Set 1 | kemijarvi
# Processing Record 170 of Set 1 | upernavik
# Processing Record 171 of Set 1 | manicore
# Processing Record 172 of Set 1 | verkhnyaya toyma
# Processing Record 173 of Set 1 | cockburn town
# Processing Record 174 of Set 1 | los llanos de aridane
# Processing Record 175 of Set 1 | hudson
# Processing Record 176 of Set 1 | sortavala
# Processing Record 177 of Set 1 | langsa
# City not found. Skipping...
# Processing Record 179 of Set 1 | del rio
# Processing Record 180 of Set 1 | te anau
# Processing Record 181 of Set 1 | hambantota
# Processing Record 182 of Set 1 | sosnovo
# Processing Record 183 of Set 1 | ruteng
# Processing Record 184 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 186 of Set 1 | broome
# Processing Record 187 of Set 1 | saint-joseph
# Processing Record 188 of Set 1 | pevek
# Processing Record 189 of Set 1 | tabou
# Processing Record 190 of Set 1 | arman
# Processing Record 191 of Set 1 | berlevag
# Processing Record 192 of Set 1 | moron
# Processing Record 193 of Set 1 | vizinga
# Processing Record 194 of Set 1 | veraval
# Processing Record 195 of Set 1 | rawson
# Processing Record 196 of Set 1 | hibbing
# Processing Record 197 of Set 1 | lang suan
# Processing Record 198 of Set 1 | vostok
# Processing Record 199 of Set 1 | matiari
# Processing Record 200 of Set 1 | kamir
# Processing Record 201 of Set 1 | klaksvik
# Processing Record 202 of Set 1 | along
# City not found. Skipping...
# Processing Record 204 of Set 1 | nan
# Processing Record 205 of Set 1 | erding
# Processing Record 206 of Set 1 | kirakira
# Processing Record 207 of Set 1 | jumla
# Processing Record 208 of Set 1 | sorong
# Processing Record 209 of Set 1 | waynesville
# Processing Record 210 of Set 1 | olafsvik
# Processing Record 211 of Set 1 | thompson
# Processing Record 212 of Set 1 | tahe
# Processing Record 213 of Set 1 | talagang
# Processing Record 214 of Set 1 | bossangoa
# Processing Record 215 of Set 1 | baruun-urt
# Processing Record 216 of Set 1 | zabol
# Processing Record 217 of Set 1 | touros
# Processing Record 218 of Set 1 | flin flon
# Processing Record 219 of Set 1 | fereydun kenar
# Processing Record 220 of Set 1 | mali
# Processing Record 221 of Set 1 | chuy
# Processing Record 222 of Set 1 | brae
# City not found. Skipping...
# Processing Record 224 of Set 1 | alexandria
# Processing Record 225 of Set 1 | margate
# Processing Record 226 of Set 1 | ilhabela
# Processing Record 227 of Set 1 | haldensleben
# Processing Record 228 of Set 1 | batsfjord
# Processing Record 229 of Set 1 | la palma
# Processing Record 230 of Set 1 | jijiga
# City not found. Skipping...
# Processing Record 232 of Set 1 | skjervoy
# Processing Record 233 of Set 1 | baragua
# Processing Record 234 of Set 1 | nalut
# Processing Record 235 of Set 1 | gongzhuling
# City not found. Skipping...
# Processing Record 237 of Set 1 | tuatapere
# City not found. Skipping...
# Processing Record 239 of Set 1 | padang
# Processing Record 240 of Set 1 | cidreira
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 243 of Set 1 | buin
# Processing Record 244 of Set 1 | port hardy
# Processing Record 245 of Set 1 | sovetskiy
# Processing Record 246 of Set 1 | sisimiut
# Processing Record 247 of Set 1 | presidencia roque saenz pena
# Processing Record 248 of Set 1 | bandrele
# Processing Record 249 of Set 1 | talnakh
# Processing Record 250 of Set 1 | emba
# Processing Record 251 of Set 1 | lompoc
# Processing Record 252 of Set 1 | teguldet
# Processing Record 253 of Set 1 | jimenez
# Processing Record 254 of Set 1 | carutapera
# Processing Record 255 of Set 1 | mayya
# Processing Record 256 of Set 1 | saint-pierre
# Processing Record 257 of Set 1 | avera
# Processing Record 258 of Set 1 | bonthe
# Processing Record 259 of Set 1 | konin
# Processing Record 260 of Set 1 | chapais
# Processing Record 261 of Set 1 | cedar falls
# City not found. Skipping...
# Processing Record 263 of Set 1 | katsuura
# Processing Record 264 of Set 1 | bolkhov
# Processing Record 265 of Set 1 | luleburgaz
# Processing Record 266 of Set 1 | grafton
# Processing Record 267 of Set 1 | pryazha
# Processing Record 268 of Set 1 | severo-kurilsk
# Processing Record 269 of Set 1 | barrow
# Processing Record 270 of Set 1 | kasungu
# Processing Record 271 of Set 1 | navolato
# City not found. Skipping...
# Processing Record 273 of Set 1 | timra
# Processing Record 274 of Set 1 | ugoofaaru
# Processing Record 275 of Set 1 | launceston
# Processing Record 276 of Set 1 | carnarvon
# Processing Record 277 of Set 1 | necochea
# Processing Record 278 of Set 1 | qinhuangdao
# Processing Record 279 of Set 1 | praia da vitoria
# Processing Record 280 of Set 1 | san antero
# Processing Record 281 of Set 1 | hirara
# Processing Record 282 of Set 1 | nuristan
# City not found. Skipping...
# Processing Record 284 of Set 1 | garden city
# Processing Record 285 of Set 1 | port alfred
# Processing Record 286 of Set 1 | batemans bay
# Processing Record 287 of Set 1 | castleford
# Processing Record 288 of Set 1 | xuanhua
# City not found. Skipping...
# Processing Record 290 of Set 1 | illela
# Processing Record 291 of Set 1 | quatre cocos
# Processing Record 292 of Set 1 | zyryanovsk
# Processing Record 293 of Set 1 | ridgecrest
# Processing Record 294 of Set 1 | ndele
# City not found. Skipping...
# Processing Record 296 of Set 1 | tiksi
# Processing Record 297 of Set 1 | norman wells
# Processing Record 298 of Set 1 | xinglongshan
# Processing Record 299 of Set 1 | coroata
# City not found. Skipping...
# Processing Record 301 of Set 1 | pontian kecil
# Processing Record 302 of Set 1 | kendari
# Processing Record 303 of Set 1 | walvis bay
# Processing Record 304 of Set 1 | sechura
# Processing Record 305 of Set 1 | litovko
# Processing Record 306 of Set 1 | heinola
# Processing Record 307 of Set 1 | tura
# Processing Record 308 of Set 1 | buala
# Processing Record 309 of Set 1 | geraldton
# Processing Record 310 of Set 1 | hinton
# Processing Record 311 of Set 1 | atar
# Processing Record 312 of Set 1 | boa vista
# Processing Record 313 of Set 1 | nanortalik
# Processing Record 314 of Set 1 | mapiripan
# Processing Record 315 of Set 1 | laguna
# Processing Record 316 of Set 1 | port hawkesbury
# Processing Record 317 of Set 1 | tibiri
# Processing Record 318 of Set 1 | lakes entrance
# Processing Record 319 of Set 1 | namibe
# Processing Record 320 of Set 1 | najran
# Processing Record 321 of Set 1 | ust-nera
# Processing Record 322 of Set 1 | shingu
# Processing Record 323 of Set 1 | vila franca do campo
# Processing Record 324 of Set 1 | borsa
# Processing Record 325 of Set 1 | vammala
# Processing Record 326 of Set 1 | maun
# Processing Record 327 of Set 1 | rincon
# Processing Record 328 of Set 1 | raudeberg
# Processing Record 329 of Set 1 | constantine
# Processing Record 330 of Set 1 | ahipara
# Processing Record 331 of Set 1 | marsaxlokk
# Processing Record 332 of Set 1 | katangli
# Processing Record 333 of Set 1 | boyuibe
# Processing Record 334 of Set 1 | bereda
# Processing Record 335 of Set 1 | maroantsetra
# Processing Record 336 of Set 1 | saint george
# Processing Record 337 of Set 1 | milkovo
# Processing Record 338 of Set 1 | sitka
# Processing Record 339 of Set 1 | buchanan
# Processing Record 340 of Set 1 | plettenberg bay
# Processing Record 341 of Set 1 | nizhniy kuranakh
# Processing Record 342 of Set 1 | alofi
# Processing Record 343 of Set 1 | batagay-alyta
# Processing Record 344 of Set 1 | constitucion
# Processing Record 345 of Set 1 | sayat
# Processing Record 346 of Set 1 | syamzha
# Processing Record 347 of Set 1 | rudnogorsk
# City not found. Skipping...
# Processing Record 349 of Set 1 | sakakah
# Processing Record 350 of Set 1 | nova vodolaha
# Processing Record 351 of Set 1 | srednekolymsk
# Processing Record 352 of Set 1 | emerald
# Processing Record 353 of Set 1 | acari
# Processing Record 354 of Set 1 | porto walter
# Processing Record 355 of Set 1 | aden
# Processing Record 356 of Set 1 | tahoua
# Processing Record 357 of Set 1 | nome
# Processing Record 358 of Set 1 | tessalit
# Processing Record 359 of Set 1 | caborca
# Processing Record 360 of Set 1 | ugento
# Processing Record 361 of Set 1 | dicabisagan
# Processing Record 362 of Set 1 | kingsville
# Processing Record 363 of Set 1 | ribeira grande
# Processing Record 364 of Set 1 | miajadas
# Processing Record 365 of Set 1 | puerto madero
# Processing Record 366 of Set 1 | goksun
# Processing Record 367 of Set 1 | bubaque
# Processing Record 368 of Set 1 | mongoumba
# Processing Record 369 of Set 1 | havre-saint-pierre
# Processing Record 370 of Set 1 | letka
# Processing Record 371 of Set 1 | gladstone
# Processing Record 372 of Set 1 | port moresby
# Processing Record 373 of Set 1 | kavieng
# Processing Record 374 of Set 1 | ilo
# Processing Record 375 of Set 1 | wilmington
# Processing Record 376 of Set 1 | wagar
# Processing Record 377 of Set 1 | fairbanks
# Processing Record 378 of Set 1 | havelock
# Processing Record 379 of Set 1 | pathein
# Processing Record 380 of Set 1 | zhanakorgan
# Processing Record 381 of Set 1 | tazovskiy
# Processing Record 382 of Set 1 | takoradi
# Processing Record 383 of Set 1 | nabire
# Processing Record 384 of Set 1 | hualmay
# Processing Record 385 of Set 1 | charters towers
# Processing Record 386 of Set 1 | botwood
# Processing Record 387 of Set 1 | lubaczow
# Processing Record 388 of Set 1 | mount gambier
# Processing Record 389 of Set 1 | bajil
# Processing Record 390 of Set 1 | limoux
# Processing Record 391 of Set 1 | rokupr
# Processing Record 392 of Set 1 | peniche
# Processing Record 393 of Set 1 | cururupu
# Processing Record 394 of Set 1 | eloy
# Processing Record 395 of Set 1 | tolyatti
# Processing Record 396 of Set 1 | high level
# Processing Record 397 of Set 1 | sakata
# Processing Record 398 of Set 1 | kyra
# Processing Record 399 of Set 1 | barahona
# Processing Record 400 of Set 1 | aktas
# Processing Record 401 of Set 1 | sabha
# Processing Record 402 of Set 1 | awjilah
# Processing Record 403 of Set 1 | port macquarie
# Processing Record 404 of Set 1 | les cayes
# Processing Record 405 of Set 1 | chimoio
# Processing Record 406 of Set 1 | awbari
# Processing Record 407 of Set 1 | turukhansk
# Processing Record 408 of Set 1 | san carlos
# Processing Record 409 of Set 1 | urumqi
# Processing Record 410 of Set 1 | weligama
# Processing Record 411 of Set 1 | hami
# Processing Record 412 of Set 1 | zhanaozen
# Processing Record 413 of Set 1 | rudbar
# Processing Record 414 of Set 1 | san ramon de la nueva oran
# Processing Record 415 of Set 1 | escanaba
# Processing Record 416 of Set 1 | zholymbet
# Processing Record 417 of Set 1 | isangel
# Processing Record 418 of Set 1 | tank
# Processing Record 419 of Set 1 | newport
# Processing Record 420 of Set 1 | salaga
# Processing Record 421 of Set 1 | balabac
# Processing Record 422 of Set 1 | olinda
# Processing Record 423 of Set 1 | pijijiapan
# Processing Record 424 of Set 1 | bangangte
# Processing Record 425 of Set 1 | merrill
# Processing Record 426 of Set 1 | dargaville
# Processing Record 427 of Set 1 | dyersburg
# City not found. Skipping...
# Processing Record 429 of Set 1 | kingisepp
# Processing Record 430 of Set 1 | half moon bay
# Processing Record 431 of Set 1 | salinopolis
# Processing Record 432 of Set 1 | bardiyah
# City not found. Skipping...
# Processing Record 434 of Set 1 | cayenne
# Processing Record 435 of Set 1 | babushkin
# Processing Record 436 of Set 1 | tezu
# Processing Record 437 of Set 1 | ust-tsilma
# Processing Record 438 of Set 1 | aykhal
# Processing Record 439 of Set 1 | namwala
# Processing Record 440 of Set 1 | namatanai
# Processing Record 441 of Set 1 | yumen
# Processing Record 442 of Set 1 | kindu
# Processing Record 443 of Set 1 | havre
# Processing Record 444 of Set 1 | shipunovo
# Processing Record 445 of Set 1 | verkhoyansk
# Processing Record 446 of Set 1 | baykit
# Processing Record 447 of Set 1 | bud
# Processing Record 448 of Set 1 | vardo
# Processing Record 449 of Set 1 | saldanha
# Processing Record 450 of Set 1 | birao
# Processing Record 451 of Set 1 | yerbogachen
# Processing Record 452 of Set 1 | rio grande
# City not found. Skipping...
# Processing Record 454 of Set 1 | devecser
# Processing Record 455 of Set 1 | dickson
# City not found. Skipping...
# Processing Record 457 of Set 1 | cap-aux-meules
# Processing Record 458 of Set 1 | marabba
# Processing Record 459 of Set 1 | cloquet
# Processing Record 460 of Set 1 | zorgo
# Processing Record 461 of Set 1 | kirillov
# Processing Record 462 of Set 1 | southbridge
# Processing Record 463 of Set 1 | saryozek
# City not found. Skipping...
# Processing Record 465 of Set 1 | marrakesh
# Processing Record 466 of Set 1 | pisco
# Processing Record 467 of Set 1 | mollendo
# Processing Record 468 of Set 1 | phangnga
# Processing Record 469 of Set 1 | dera bugti
# Processing Record 470 of Set 1 | south lake tahoe
# City not found. Skipping...
# Processing Record 472 of Set 1 | gorontalo
# Processing Record 473 of Set 1 | pakxan
# Processing Record 474 of Set 1 | santo angelo
# Processing Record 475 of Set 1 | jinchang
# Processing Record 476 of Set 1 | khomutovo
# Processing Record 477 of Set 1 | cabo san lucas
# Processing Record 478 of Set 1 | provideniya
# Processing Record 479 of Set 1 | middelburg
# City not found. Skipping...
# Processing Record 481 of Set 1 | anadyr
# City not found. Skipping...
# Processing Record 483 of Set 1 | porto novo
# Processing Record 484 of Set 1 | bathsheba
# Processing Record 485 of Set 1 | agutaya
# Processing Record 486 of Set 1 | fortuna
# Processing Record 487 of Set 1 | jos
# Processing Record 488 of Set 1 | bayan
# Processing Record 489 of Set 1 | muros
# Processing Record 490 of Set 1 | san javier
# Processing Record 491 of Set 1 | amapa
# Processing Record 492 of Set 1 | bhawana
# Processing Record 493 of Set 1 | evansville
# Processing Record 494 of Set 1 | beisfjord
# Processing Record 495 of Set 1 | morondava
# Processing Record 496 of Set 1 | energetik
# City not found. Skipping...
# Processing Record 498 of Set 1 | delemont
# Processing Record 499 of Set 1 | alta floresta
# City not found. Skipping...
# Processing Record 501 of Set 1 | naron
# Processing Record 502 of Set 1 | mount pleasant
# Processing Record 503 of Set 1 | sambava
# City not found. Skipping...
# Processing Record 505 of Set 1 | makakilo city
# Processing Record 506 of Set 1 | lusambo
# Processing Record 507 of Set 1 | kontagora
# Processing Record 508 of Set 1 | hamilton
# Processing Record 509 of Set 1 | sur
# Processing Record 510 of Set 1 | saint anthony
# Processing Record 511 of Set 1 | pokosnoye
# Processing Record 512 of Set 1 | otradnoye
# Processing Record 513 of Set 1 | russkaya polyana
# Processing Record 514 of Set 1 | sinnamary
# Processing Record 515 of Set 1 | huron
# Processing Record 516 of Set 1 | babstovo
# Processing Record 517 of Set 1 | nortelandia
# Processing Record 518 of Set 1 | oksfjord
# Processing Record 519 of Set 1 | rabo de peixe
# Processing Record 520 of Set 1 | jalu
# Processing Record 521 of Set 1 | auki
# Processing Record 522 of Set 1 | dinguiraye
# Processing Record 523 of Set 1 | damaturu
# Processing Record 524 of Set 1 | westport
# Processing Record 525 of Set 1 | manono
# Processing Record 526 of Set 1 | ishigaki
# Processing Record 527 of Set 1 | kudahuvadhoo
# Processing Record 528 of Set 1 | cutro
# Processing Record 529 of Set 1 | putyatino
# Processing Record 530 of Set 1 | kalach-na-donu
# Processing Record 531 of Set 1 | izyaslav
# Processing Record 532 of Set 1 | mehamn
# Processing Record 533 of Set 1 | siverek
# Processing Record 534 of Set 1 | barra da estiva
# Processing Record 535 of Set 1 | datong
# Processing Record 536 of Set 1 | banff
# City not found. Skipping...
# Processing Record 538 of Set 1 | clyde river
# Processing Record 539 of Set 1 | tual
# Processing Record 540 of Set 1 | shalakusha
# Processing Record 541 of Set 1 | hailey
# Processing Record 542 of Set 1 | rocha
# Processing Record 543 of Set 1 | matara
# Processing Record 544 of Set 1 | bonfim
# Processing Record 545 of Set 1 | meulaboh
# City not found. Skipping...
# Processing Record 547 of Set 1 | kahului
# Processing Record 548 of Set 1 | hohhot
# Processing Record 549 of Set 1 | sao filipe
# Processing Record 550 of Set 1 | humaita
# City not found. Skipping...
# Processing Record 552 of Set 1 | ninh binh
# Processing Record 553 of Set 1 | cilegon
# Processing Record 554 of Set 1 | lagoa
# Processing Record 555 of Set 1 | shimoda
# Processing Record 556 of Set 1 | luganville
# Processing Record 557 of Set 1 | caravelas
# Processing Record 558 of Set 1 | pafos
# Processing Record 559 of Set 1 | farmington
# Processing Record 560 of Set 1 | burg
# Processing Record 561 of Set 1 | xining
# Processing Record 562 of Set 1 | lethem
# Processing Record 563 of Set 1 | fort saint james
# Processing Record 564 of Set 1 | mumford
# Processing Record 565 of Set 1 | balkanabat
# Processing Record 566 of Set 1 | kangaatsiaq
# Processing Record 567 of Set 1 | alyangula
# Processing Record 568 of Set 1 | korla
# Processing Record 569 of Set 1 | nisia floresta
# Processing Record 570 of Set 1 | mackenzie
# Processing Record 571 of Set 1 | comodoro rivadavia
# Processing Record 572 of Set 1 | cotacachi
# Processing Record 573 of Set 1 | ceuta
# City not found. Skipping...
# Processing Record 575 of Set 1 | iberia
# Processing Record 576 of Set 1 | coahuayana
# Processing Record 577 of Set 1 | adre
# Processing Record 578 of Set 1 | salalah
# Processing Record 579 of Set 1 | okha
# Processing Record 580 of Set 1 | mookane
# Processing Record 581 of Set 1 | zanjan
# Processing Record 582 of Set 1 | ruwi
# Processing Record 583 of Set 1 | boende
# Processing Record 584 of Set 1 | sinjar
# Processing Record 585 of Set 1 | evensk
# Processing Record 586 of Set 1 | corralillo
# Processing Record 587 of Set 1 | talara
# Processing Record 588 of Set 1 | guerrero negro
# Processing Record 589 of Set 1 | itacarambi
# Processing Record 590 of Set 1 | whitecourt
# City not found. Skipping...
# Processing Record 592 of Set 1 | pervomayskiy
# Processing Record 593 of Set 1 | la estrella
# Processing Record 594 of Set 1 | zaigrayevo
# Processing Record 595 of Set 1 | mount isa
# Processing Record 596 of Set 1 | kayes
# Processing Record 597 of Set 1 | oron
# Processing Record 598 of Set 1 | nelidovo
# Processing Record 599 of Set 1 | ambilobe
# Processing Record 600 of Set 1 | minab
# Processing Record 601 of Set 1 | birobidzhan
# Processing Record 602 of Set 1 | ventspils
# Processing Record 603 of Set 1 | chalus
# Processing Record 604 of Set 1 | vila
# Processing Record 605 of Set 1 | laredo
# City not found. Skipping...
# Processing Record 607 of Set 1 | sept-iles
# Processing Record 608 of Set 1 | souillac
# Processing Record 609 of Set 1 | adrar
# Processing Record 610 of Set 1 | taoudenni
# Processing Record 611 of Set 1 | san patricio
# Processing Record 612 of Set 1 | port lincoln
# Processing Record 613 of Set 1 | puerto quijarro
# City not found. Skipping...
# Processing Record 615 of Set 1 | athabasca
# Processing Record 616 of Set 1 | port shepstone
# Processing Record 617 of Set 1 | prince rupert
# Processing Record 618 of Set 1 | atchison
# Processing Record 619 of Set 1 | labuhan
# Processing Record 620 of Set 1 | bichena
# Processing Record 621 of Set 1 | tienen
# Processing Record 622 of Set 1 | lensk
# Processing Record 623 of Set 1 | maracacume
# Processing Record 624 of Set 1 | khasan
# Processing Record 625 of Set 1 | piacabucu
# Processing Record 626 of Set 1 | hartford
# Processing Record 627 of Set 1 | ketchikan
# Processing Record 628 of Set 1 | paragominas
# Processing Record 629 of Set 1 | marienburg
# Processing Record 630 of Set 1 | honavar
# City not found. Skipping...
# Processing Record 632 of Set 1 | san angelo
# Processing Record 633 of Set 1 | port-gentil
# Processing Record 634 of Set 1 | christchurch

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data = pd.DataFrame({'City': city_list,'Temperature_Max': temp,'Latitude': lat, 'Longitude': lon,
                          'Humidity %': humidity_percent,'Cloudiness %':cloudiness_percent,
                         'Wind Speed': wind_speed})
city_data.to_csv(output_data_file, index = False, header = True)

# %%
city_data.head()
# Out:
#                 City  Temperature_Max  Latitude  Longitude  Humidity %  \
# 0              Pakse            33.00     15.12     105.78          46
# 1             Taltal            15.27    -25.40     -70.48          89
# 2         Bredasdorp            15.00    -34.53      20.04          93
# 3              Kapaa            25.00     22.08    -159.32          69
# 4  Saint Paul Harbor             5.00     57.79    -152.41          48
#
#    Cloudiness %  Wind Speed
# 0            40        1.00
# 1             7        2.00
# 2            18        1.00
# 3            90        4.68
# 4             1       13.90

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#setting today's date 
d= datetime.today().strftime('%m-%d-%y')

# %%
latitude = [lat for lat in city_data['Latitude']]
temp = [temp for temp in city_data['Temperature_Max']]

plt.scatter(latitude, temp, facecolors="magenta", edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title(f"City Latitude vs. Max Temperature ({d})")
plt.grid()

latitude = np.array(latitude)
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, temp)
regress_values = latitude * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(latitude, regress_values, "b-")
r_squared = "The r-squared is:"+ str(round(rvalue,2))
plt.annotate(r_squared,(-40,-25), fontsize=15)

plt.savefig("../output_data/Fig1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
humidity = [humidity for humidity in city_data['Humidity %']]

plt.scatter(latitude, humidity, facecolors="magenta", edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity ({d})")
plt.grid()

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, humidity)
regress_values = latitude * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(latitude, regress_values, "blue")
r_squared = "The r-squared is:"+ str(round(rvalue,2))
plt.annotate(r_squared,(-60,10), fontsize=10)

plt.savefig("../output_data/Fig2.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
cloudiness = [cloudiness for cloudiness in city_data['Cloudiness %']]

plt.scatter(latitude, cloudiness, facecolors="magenta", edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs. Cloudiness ({d})")
plt.grid()

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, cloudiness)
regress_values = latitude * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(latitude, regress_values, "blue")
r_squared = "The r-squared is:"+ str(round(rvalue,2))
plt.annotate(r_squared,(-60,50), fontsize=15)

plt.savefig("../output_data/Fig3.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
wind = [wind for wind in city_data['Wind Speed']]

plt.scatter(latitude, wind, facecolors="magenta", edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs. Wind Speed ({d})")
plt.grid()

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, wind)
regress_values = latitude * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(latitude, regress_values, "blue")
r_squared = "The r-squared is:"+ str(round(rvalue,2))
plt.annotate(r_squared,(-40,17), fontsize=15)

plt.savefig("../output_data/Fig4.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
#see above

# %%
# Create Northern and Southern Hemisphere DataFrames
northernHemisphere = city_data.loc[city_data['Latitude']>=0]
northernHemisphere

southernHemisphere = city_data.loc[city_data['Latitude']<0]
southernHemisphere
# Out:
#              City  Temperature_Max  Latitude  Longitude  Humidity %  \
# 1          Taltal            15.27    -25.40     -70.48          89
# 2      Bredasdorp            15.00    -34.53      20.04          93
# 5       Esperance            22.00    -33.87     121.90          56
# 7         Mataura             6.11    -46.19     168.86          81
# 8         Rikitea            25.97    -23.12    -134.97          70
# ..            ...              ...       ...        ...         ...
# 577    Maracaçumé            22.27     -2.04     -45.96          96
# 579     Piaçabuçu            25.97    -10.41     -36.43          83
# 582   Paragominas            22.17     -2.97     -47.48          98
# 586   Port-Gentil            27.77     -0.72       8.78          80
# 587  Christchurch            20.00    -43.53     172.63          77
#
#      Cloudiness %  Wind Speed
# 1               7        2.00
# 2              18        1.00
# 5              75        3.10
# 7              86        5.36
# 8              80        0.24
# ..            ...         ...
# 577            95        0.62
# 579            33        2.54
# 582            87        0.57
# 586            70        4.63
# 587            55        5.10
#
# [165 rows x 7 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitudeNorthern = [lat for lat in northernHemisphere['Latitude']]
tempNorthern = [temp for temp in northernHemisphere['Temperature_Max']]

plt.scatter(latitudeNorthern, tempNorthern)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Northern Hemisphere: City Latitude vs. Max Temperature ()")

latitudeNorthern = np.array(latitudeNorthern)
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitudeNorthern, tempNorthern)
regress_values = latitudeNorthern * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(latitudeNorthern, regress_values, "r-")
print(f"The r-squared is: {rvalue}")

plt.annotate(line_eq,(5,-10), fontsize=15, color='red')
plt.show()
# Out:
# The r-squared is: -0.8926489407652832

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitudeSouthern = [lat for lat in southernHemisphere['Latitude']]
tempSouthern = [temp for temp in southernHemisphere['Temperature_Max']]

plt.scatter(latitudeSouthern, tempSouthern)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Southern Hemisphere: City Latitude vs. Max Temperature ()")

latitudeSouthern = np.array(latitudeSouthern)
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitudeSouthern, tempSouthern)
regress_values = latitudeSouthern * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(latitudeSouthern, regress_values, "r-")
print(f"The r-squared is: {rvalue}")

plt.annotate(line_eq,(-55,30), fontsize=15, color='red')
plt.show()
# Out:
# The r-squared is: 0.6258635108470297

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
humidityNorthern = [humidity for humidity in northernHemisphere['Humidity %']]

plt.scatter(latitudeNorthern, humidityNorthern)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Northern Hemisphere: City Latitude vs. Humidity ()")

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitudeNorthern, humidityNorthern)
regress_values = latitudeNorthern * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(latitudeNorthern, regress_values, "r-")
print(f"The r-squared is: {rvalue}")

plt.annotate(line_eq,(45,20), fontsize=15, color='red')
plt.show()
# Out:
# The r-squared is: 0.23370876748151873

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
humiditySouthern = [humidity for humidity in southernHemisphere['Humidity %']]

plt.scatter(latitudeSouthern, humiditySouthern)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Southern Hemisphere: City Latitude vs. Humidity ()")

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitudeSouthern, humiditySouthern)
regress_values = latitudeSouthern * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(latitudeSouthern, regress_values, "r-")
print(f"The r-squared is: {rvalue}")

plt.annotate(line_eq,(-35,30), fontsize=15, color='red')
plt.show()
# Out:
# The r-squared is: 0.27585272683787493

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
cloudinessNorthern = [cloudiness for cloudiness in northernHemisphere['Cloudiness %']]

plt.scatter(latitudeNorthern, cloudinessNorthern)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hemisphere: City Latitude vs. Cloudiness ()")

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitudeNorthern, cloudinessNorthern)
regress_values = latitudeNorthern * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(latitudeNorthern, regress_values, "r-")
print(f"The r-squared is: {rvalue}")

plt.annotate(line_eq,(22,50), fontsize=15, color='red')
plt.show()
# Out:
# The r-squared is: 0.14351409123947886

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
cloudinessSouthern = [cloudiness for cloudiness in southernHemisphere['Cloudiness %']]

plt.scatter(latitudeSouthern, cloudinessSouthern)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hemisphere: City Latitude vs. Cloudiness ()")

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitudeSouthern, cloudinessSouthern)
regress_values = latitudeSouthern * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(latitudeSouthern, regress_values, "r-")
print(f"The r-squared is: {rvalue}")

plt.annotate(line_eq,(-55,8), fontsize=15, color='red')
plt.show()
# Out:
# The r-squared is: 0.16879269472547706

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
windNorthern = [wind for wind in northernHemisphere['Wind Speed']]

plt.scatter(latitudeNorthern, windNorthern)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Northern Hemisphere: City Latitude vs. Wind Speed ()")

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitudeNorthern, windNorthern)
regress_values = latitudeNorthern * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(latitudeNorthern, regress_values, "r-")
print(f"The r-squared is: {rvalue}")

plt.annotate(line_eq,(5,17), fontsize=15, color='red')
plt.show()
# Out:
# The r-squared is: 0.29079683400101186

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
windSouthern = [wind for wind in southernHemisphere['Wind Speed']]

plt.scatter(latitudeSouthern, windSouthern)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Southern Hemisphere: City Latitude vs. Wind Speed ()")

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitudeSouthern, windSouthern)
regress_values = latitudeSouthern * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(latitudeSouthern, regress_values, "r-")
print(f"The r-squared is: {rvalue}")

plt.annotate(line_eq,(-55,10), fontsize=15, color='red')
plt.show()
# Out:
# The r-squared is: -0.3737819165827444
